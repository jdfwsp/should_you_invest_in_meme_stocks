# %%
import pandas as pd
from functools import reduce

import panel as pn

from panel.interact import interact, interactive, fixed, interact_manual
from panel import widgets

pn.extension()

# %%
spy = pd.read_csv('../Data/SPY_Data.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
it_min = pd.read_csv('../Data/IT_Min_ORCL.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
it_med = pd.read_csv('../Data/IT_Med_NTAP.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
it_max = pd.read_csv('../Data/IT_Max_ENPH.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
it_mut = pd.read_csv('../Data/IT_Fund_VGT.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
health_min = pd.read_csv('../Data/Healthcare_Min_DGX.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
health_med = pd.read_csv('../Data/Healthcare_Median_CAH.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
health_max = pd.read_csv('../Data/Healthcare_Max_ALGN.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
health_mut = pd.read_csv('../Data/Healthcare_Mutual_VHT.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
finance_min = pd.read_csv('../Data/Fin_Min_CBOE.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
finance_med = pd.read_csv('../Data/Fin_Med_BAC.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
finance_max = pd.read_csv('../Data/Fin_Max_LNC.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
finance_mut = pd.read_csv('../Data/Fin_Fund_VFH.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
disc_min = pd.read_csv('../Data/Consumer_Discretionary_Min_NVR.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
disc_med = pd.read_csv('../Data/Consumer_Discretionary_Median_HLT.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
disc_max = pd.read_csv('../Data/Consumer_Discretionary_Max_F.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
disc_mut = pd.read_csv('../Data/Consumer_Discretionary_Mutual_VCR.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
comms_min = pd.read_csv('../Data/Communication_Min_VZ.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
comms_med = pd.read_csv('../Data/Communications_Med_TMUS.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
comms_max = pd.read_csv('../Data/Communication_Max_LYV.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
comms_mut = pd.read_csv('../Data/Communication_Fund_VOX.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
industry_min = pd.read_csv('../Data/Industrial_Min_NOC.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
industry_med = pd.read_csv('../Data/Industrial_Median_DE.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
industry_max = pd.read_csv('../Data/Industrial_Max_TDG.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
industry_mut = pd.read_csv('../Data/Industrial_Mutual_VIS.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
staple_min = pd.read_csv('../Data/Consumer_Staple_Min_CLX.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
staple_med = pd.read_csv('../Data/Consumer_Staples_Median_PM.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
staple_max = pd.read_csv('../Data/Consumer_Staples_Max_SYY.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
staple_mut = pd.read_csv('../Data/Consumer_Staples_Mutual_VDC.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
energy_min = pd.read_csv('../Data/Energy_Min_COG.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
energy_med = pd.read_csv('../Data/Energy_Med_SLB.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
energy_max = pd.read_csv('../Data/Energy_Max_OXY.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
energy_mut = pd.read_csv('../Data/Energy_Fund_VDE.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
util_min = pd.read_csv('../Data/Util_Min_ED.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
util_med = pd.read_csv('../Data/Util_Med_SRE.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
util_max = pd.read_csv('../Data/Util_Max_AES.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
util_mut = pd.read_csv('../Data/Util_Fund_VPU.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
real_min = pd.read_csv('../Data/Real_Estate_Min_PSA.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
real_med = pd.read_csv('../Data/Real_Estate_Median_UDR.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
real_max = pd.read_csv('../Data/Real_Estate_Max_SPG.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
real_mut = pd.read_csv('../Data/Real_Estate_Mutual_VNQ.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
materials_min = pd.read_csv('../Data/Materials_Min_NEM.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
materials_med = pd.read_csv('../Data/Materials_Med_AVY.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
materials_max = pd.read_csv('../Data/Materials_Max_FCX.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')
materials_mut = pd.read_csv('../Data/Materials_Fund_VAW.csv', infer_datetime_format=True, parse_dates=True, index_col='Date')

# %%
port_min = [spy['Close'], it_min['Close'], health_min['Close'], finance_min['Close'], disc_min['Close'], comms_min['Close'], industry_min['Close'], staple_min['Close'], energy_min['Close'], util_min['Close'], real_min['Close'], materials_min['Close']]
port_med = [spy['Close'], it_med['Close'], health_med['Close'], finance_med['Close'], disc_med['Close'], comms_med['Close'], industry_med['Close'], staple_med['Close'], energy_med['Close'], util_med['Close'], real_med['Close'], materials_med['Close']]
port_max = [spy['Close'], it_max['Close'], health_max['Close'], finance_max['Close'], disc_max['Close'], comms_max['Close'], industry_max['Close'], staple_max['Close'], energy_max['Close'], util_max['Close'], real_max['Close'], materials_max['Close']]
port_mut = [spy['Close'], it_mut['Close'], health_mut['Close'], finance_mut['Close'], disc_mut['Close'], comms_mut['Close'], industry_mut['Close'], staple_mut['Close'], energy_mut['Close'], util_mut['Close'], real_mut['Close'], materials_mut['Close']]

# %%
min_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'], how='inner'), port_min)
min_merged.columns = ['SPY', 'IT', 'Health', 'Finance', 'Discretionary', 'Communications', 'Industrials', 'Staples', 'Energy', 'Utilities', 'Real Estate', 'Materials']
med_merged = reduce(lambda left, right: pd.merge(left, right, on = ['Date'], how = 'inner'), port_med)
med_merged.columns = ['SPY', 'IT', 'Health', 'Finance', 'Discretionary', 'Communications', 'Industrials', 'Staples', 'Energy', 'Utilities', 'Real Estate', 'Materials']
max_merged = reduce(lambda   left, right: pd.merge(left, right, on = ['Date'], how = 'inner'), port_max)
max_merged.columns = ['SPY', 'IT', 'Health', 'Finance', 'Discretionary', 'Communications', 'Industrials', 'Staples', 'Energy', 'Utilities', 'Real Estate', 'Materials']
mut_merged = reduce(lambda   left, right: pd.merge(left, right, on = ['Date'], how = 'inner'), port_mut)
mut_merged.columns = ['SPY', 'IT', 'Health', 'Finance', 'Discretionary', 'Communications', 'Industrials', 'Staples', 'Energy', 'Utilities', 'Real Estate', 'Materials']

# %%
it_min.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
med_fig = med_merged.plot.line(figsize = (30, 24))

# %%
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=30, name='x', start=-10, value=10)
#     [1] Row
#         [0] Str(int, name='interactive00099')

# %%
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=15, name='p', start=-5, value=5)
#     [1] Row
#         [0] Str(tuple, name='interactive00118')
